# %%
import pandas
zvirata = pandas.read_csv("adopce-zvirat.csv", sep=";")
zvirata


# 513 řádků, 6 sloupců, Index(['id', 'nazev_cz', 'nazev_en', 'trida_cz', 'cena', 'k_prohlidce'], dtype='object') (zvirata.columns)
# č. 34 = ibis bílý, White ibis (zvirata.iloc[34])

# BONUS:
# Nejdražší zvířata k adopci: tygr ussurijský, tygr malajský, hroch obojživelný, žirafa severní, slon indický (všichni 50 000) 
#      zvirata.sort_values("cena").tail()

# alfabeticky poslední v ČJ: žluva hajní (zvirata.sort_values("nazev_cz").tail())
# alfabeticky poslední v AJ: Yellow-necked francolin (zvirata.sort_values("nazev_en").tail())
# Out:
#      id         nazev_cz            nazev_en trida_cz  cena  k_prohlidce
# 32   97  Zejozob africký    African openbill    Ptáci  2500            1
# 33   98        Ibis rudý        Scarlet ibis    Ptáci  3000            1
# 34   99        Ibis bílý          White ibis    Ptáci  3000            1
# 35  100      Ibis skalní  Northern bald ibis    Ptáci  3000            1
# 36  102      Kolpík bílý  Eurasian spoonbill    Ptáci  3000            1
