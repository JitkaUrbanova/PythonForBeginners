# %%
import pandas as pd
import matplotlib.pyplot as plt
platy = pandas.read_csv("platy_2021_02.csv")
platy.hist()
# Out:
# array([[<Axes: title={'center': 'cislo_zamestnance'}>,
#         <Axes: title={'center': 'plat'}>]], dtype=object)

# %%
platy["plat"].hist(bins=7, color="y", edgecolor="black")
plt.show()
